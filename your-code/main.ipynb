# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns
from scipy import stats
from scipy.stats import uniform

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
#To make a list of 100 numbers between 0 and 800
uniform.rvs(2, 8, size=10)
# Out:
# array([9.95628887, 4.70243524, 2.86605309, 5.54626115, 6.20656081,
#        9.05048533, 6.98405336, 4.30832609, 7.1070497 , 8.55179534])

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# Function generation
def uniform_set(bottom,ceiling,count):
    '''
    The function will generate a uniformly distributed array
    of random numbers. 
    bottom = lower limit
    ceiling = upper limit
    count = number of values
    '''
    
    return uniform.rvs(bottom, ceiling, size=count)

# %%
s1= uniform_set(10,15,100)
s2 = uniform_set(10,60,1000)

# %%
fig,ax = plt.subplots(1,2)

sns.histplot(s1,ax=ax[0], bins = 10)
sns.histplot(s2,ax=ax[1], bins = 10)
ax[0].sharey(ax[1])
ax[1].set_ylabel('') #So it does not overlap with the first graph
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# ## Answer
# - Both distributions show no trend or prefered values, by the way the set was generated which was random.
# - The first graph has less counts because in comparison to the second,only 100 numbers; while in the second it was 1000.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
def norm_set(count,mean,std): 
    '''
    The function will return a normally distributed set of random numbers. 
        The function will generate a uniformly distributed array
    of random numbers. 
    The scipy function takes rvs(loc,scale,size)
    loc = average
    scale = standard deviation 
    size = size of the array
    '''
        
    return np.sort(norm.rvs(mean,std,count))

# %%
n1= norm_set(1000,10,1)
n2= norm_set(1000,10,50)

# %%
fig,ax = plt.subplots(1,2)

sns.histplot(n1,ax=ax[0], bins = 50, kde= True)
sns.histplot(n2,ax=ax[1], bins = 50, kde= True)
ax[0].sharey(ax[1])
ax[1].set_ylabel('') #So it does not overlap with the first graph
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# A small standard deviation, generates a distribution located close to the mean value, as seen in the first graph. However, the second set with higher standard deviation, causes the graph to extend to more positive and negative values. Because of how the sets were generated, they both show similar normal distributions.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
df = pd.read_csv("vehicles.csv")
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
# ...

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
stats1= df["Fuel Barrels/Year"].describe().to_frame()
stats1
# Out:
#        Fuel Barrels/Year
# count       35952.000000
# mean           17.609056
# std             4.467283
# min             0.060000
# 25%            14.699423
# 50%            17.347895
# 75%            20.600625
# max            47.087143

# %%
counts_1= int(stats1["Fuel Barrels/Year"].iloc[0])
mean_1= int(stats1["Fuel Barrels/Year"].iloc[1])
std_1= int(stats1["Fuel Barrels/Year"].iloc[2])

# %%
#Extracting the information about the distribution of the dataset
stats.describe(df["Fuel Barrels/Year"].values)
# Out:
# DescribeResult(nobs=np.int64(35952), minmax=(np.float64(0.06), np.float64(47.08714285714285)), mean=np.float64(17.609055502328133), variance=np.float64(19.956614599288176), skewness=np.float64(0.6382445784906978), kurtosis=np.float64(1.4679138019302096))

# %%
#Plotting the experimental distribution along with a theoretical normal distribution

plt.hist(df["Fuel Barrels/Year"], bins = 80, density = True, label= "Fuel Barrels/year")
simulation_1 = norm_set(counts_1, mean_1, std_1)
plt.plot(simulation_1,norm.pdf(simulation_1, 17.6, 4.47), label= "Simulation")
plt.legend()
plt.ylabel("Probability Density")
plt.xlabel("Fuel Barrels/year")
plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
stats2= df["CO2 Emission Grams/Mile"].describe().to_frame()
stats2
# Out:
#        CO2 Emission Grams/Mile
# count             35952.000000
# mean                475.316339
# std                 119.060773
# min                  37.000000
# 25%                 395.000000
# 50%                 467.736842
# 75%                 555.437500
# max                1269.571429

# %%
counts_2= int(stats2["CO2 Emission Grams/Mile"].iloc[0])
mean_2= int(stats2["CO2 Emission Grams/Mile"].iloc[1])
std_2= int(stats2["CO2 Emission Grams/Mile"].iloc[2])

# %%
#Extracting the information about the distribution of the dataset
stats.describe(df["CO2 Emission Grams/Mile"].values)
# Out:
# DescribeResult(nobs=np.int64(35952), minmax=(np.float64(37.0), np.float64(1269.571428571429)), mean=np.float64(475.3163392572124), variance=np.float64(14175.467723536345), skewness=np.float64(0.7416608937445333), kurtosis=np.float64(1.2632401888522518))

# %%
#Plotting the experimental distribution along with a theoretical normal distribution

plt.hist(df["CO2 Emission Grams/Mile"], bins = 80, density = True, label= "CO2 Emission Grams/Mile")
simulation_2 = norm_set(counts_2, mean_2, std_2)
plt.plot(simulation_2,norm.pdf(simulation_2,  mean_2, std_2), label= "Simulation")
plt.legend()
plt.ylabel("Probability Density")
plt.xlabel("CO2 Emission Grams/Mile")
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
stats3= df["Combined MPG"].describe().to_frame()
stats3
# Out:
#        Combined MPG
# count  35952.000000
# mean      19.929322
# std        5.112409
# min        7.000000
# 25%       16.000000
# 50%       19.000000
# 75%       23.000000
# max       56.000000

# %%
counts_3= int(stats3["Combined MPG"].iloc[0])
mean_3= int(stats3["Combined MPG"].iloc[1])
std_3= int(stats3["Combined MPG"].iloc[2])

# %%
#Extracting the information about the distribution of the dataset
stats.describe(df["Combined MPG"].values)
# Out:
# DescribeResult(nobs=np.int64(35952), minmax=(np.int64(7), np.int64(56)), mean=np.float64(19.92932242990654), variance=np.float64(26.13672521750139), skewness=np.float64(1.0677281511016457), kurtosis=np.float64(2.722005828121909))

# %%
#Plotting the experimental distribution along with a theoretical normal distribution

plt.hist(df["Combined MPG"], bins = 80, density = True, label= "Combined MPG")
simulation_3 = norm_set(counts_3, mean_3, std_3)
plt.plot(simulation_3,norm.pdf(simulation_3,mean_3, std_3), label= "Simulation")
plt.legend()
plt.ylabel("Probability Density")
plt.xlabel("Combined MPG")
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
display(stats.describe(df["Fuel Barrels/Year"].values),
stats.describe(df["CO2 Emission Grams/Mile"].values),
stats.describe(df["Combined MPG"].values))
# Out:
# DescribeResult(nobs=np.int64(35952), minmax=(np.float64(0.06), np.float64(47.08714285714285)), mean=np.float64(17.609055502328133), variance=np.float64(19.956614599288176), skewness=np.float64(0.6382445784906978), kurtosis=np.float64(1.4679138019302096))
# DescribeResult(nobs=np.int64(35952), minmax=(np.float64(37.0), np.float64(1269.571428571429)), mean=np.float64(475.3163392572124), variance=np.float64(14175.467723536345), skewness=np.float64(0.7416608937445333), kurtosis=np.float64(1.2632401888522518))
# DescribeResult(nobs=np.int64(35952), minmax=(np.int64(7), np.int64(56)), mean=np.float64(19.92932242990654), variance=np.float64(26.13672521750139), skewness=np.float64(1.0677281511016457), kurtosis=np.float64(2.722005828121909))

# %%
#Gathering compared data: 
all_stats = stats1.join(stats2, how="inner")
all_stats = all_stats.join(stats3, how="inner")
all_stats
# Out:
#        Fuel Barrels/Year  CO2 Emission Grams/Mile  Combined MPG
# count       35952.000000             35952.000000  35952.000000
# mean           17.609056               475.316339     19.929322
# std             4.467283               119.060773      5.112409
# min             0.060000                37.000000      7.000000
# 25%            14.699423               395.000000     16.000000
# 50%            17.347895               467.736842     19.000000
# 75%            20.600625               555.437500     23.000000
# max            47.087143              1269.571429     56.000000

# %% [markdown]
# Based on the histogram plots against simulated data, the data that best resembles the simulated line is the data for Fuel barrels per year.
#
# We may also use the outcome given by the function of scipy stats.
# - The skewness varies as:  0.63<0.74<1.07 for Fuel Barrels/Year< CO2 Emission Grams/Mile < Combined MPG.
# This is in agreement with the qualitative observations, although the skewness is not close to 0, as for a normal distribution.
# - The kurtosis, which describes the weight of the tail vs the main distribution does not follow this result. CO2 Emission Grams/Mile< Fuel Barrels/Year < Combined MPG. But all are positive and only the latter is closer to the expected value of 3 for a normal distribution.
# - Based on the differences between the mean value and the interquartile range, Fuel Barrels/Year also shows closer values than the others.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def exp_set(avg,count): 
    return np.random.exponential(avg,count)

# %%
#Plotting the generated exponential functions
fig,ax = plt.subplots(1,2)

exp1= exp_set(10,10)
exp2= exp_set(10,100)
sns.histplot(exp1,ax=ax[0], bins = 100)
sns.histplot(exp2,ax=ax[1], bins = 100)
ax[1].set_ylabel('') #So it does not overlap with the first graph
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
from scipy.stats import expon

# %%
#Creating the synthetic data, assuming a sample set of 200 points
avg = 10
exp = exp_set(avg,1000)

#The probability of each event will be given by the probability density distribution. 
sns.histplot(exp, bins = 100)
plt.xlim()
plt.show()

# %%
#The cumulative distribution function will give the probability of a call being taken in less than 15 min. 
x=15
CDF_exp = 1-math.exp(-(1/avg)*x)
CDF_exp
# Out:
# 0.7768698398515702

# %%
expon.cdf(x,loc=0,scale=10)
# Out:
# np.float64(0.7768698398515702)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
expon.sf(x,loc=0,scale=10)
# Out:
# np.float64(0.22313016014842982)
